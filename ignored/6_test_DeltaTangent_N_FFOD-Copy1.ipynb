# %% [markdown]
# # import and load data

# %%
# %run imports_N_loadDenoised.ipynb
# Out:
# /c/Users/junec/AppData/Local/Programs/Python/Python38/python
# load & denoise real field data===========================
# ---load data from 'txt' or 'xlsx' files...
# check the time type
# ---denoising data using S-G smoothing...
# ---The first & second order derivative has been calculated and appended to pressure dataframe
# len(ground_truth_denoised) 60
# after remove uncorrect ground truth
# len(ground_truth_denoised) 54
#        Elapsed time(hr)  Pressure(psia)  first_order_derivative  \
# count      29813.000000    29813.000000            29813.000000
# mean        1949.504754     5858.252763               30.980488
# std         1071.285888     1201.608375              217.076860
# min            0.000000     2989.186167            -1177.363679
# 25%         1223.614626     4920.227064              -26.315082
# 50%         2055.749995     5958.685278                6.577672
# 75%         2691.845828     6884.300893               50.575874
# max         4070.949737     7942.372157             1442.449150
#
#        second_order_derivative
# count             29813.000000
# mean              -3316.399705
# std               26067.263416
# min             -267661.267543
# 25%                -150.940811
# 50%                   0.048895
# 75%                 129.782625
# max              199644.890976
#        Elapsed time(hr)  Liquid rate(STB/D)
# count      10191.000000        10191.000000
# mean        2210.383315       -16880.702745
# std         1121.860526         4591.205914
# min            0.433384       -22568.277381
# 25%         1345.039547       -19746.868884
# 50%         2248.487512       -18758.998204
# 75%         3074.228818       -15911.221687
# max         4075.570423            1.166046
# [(24833, 24872), (5698, 5833), (14471, 14575), (10149, 10224)]
# 47.913402758931625
# -12.103679078019923
# 111.47517980463454
# 97.0315455031132

# %% [markdown]
# # spilit periods and find multi-rate break points

# %%
# %store -r First_FOD

# %%
# %store
# Out:
# Stored variables and their in-db values:
# First_FOD                           -> [[32, 38, 39, 41, 55, 78, 143, 266, 287, 434, 508,
# Max_FOD                             -> [[32, 38, 39, 43, 57, 79, 143, 275, 287, 434, 508,
# breakPoints_grountTruth             -> [1, 32, 272, 384, 443, 526, 608, 722, 2252, 2473,
# buildup_PR                          -> [32, 33, 34, 35, 37, 38, 39, 40, 41, 42, 43, 44, 4
# drawdown_PR                         -> [2248, 2249, 2250, 2251, 2252, 2253, 2254, 2255, 2

# %%
points_buildUp=First_FOD[0]
points_drawDown=First_FOD[1]
minor_threshold_shutIn=0.02
# minor_threshold_shutIn=0.028
# minor_threshold_shutIn=0.010
minor_threshold_Flowing=0.03
# minor_threshold_Flowing=0.015
# minor_threshold_Flowing=0.9
# %run store_transients.ipynb
# Out:
# ====detected_shutIns 34
# ====filtered_shutIns 31
# ====len(flowingPeriods) 32
# ====finally detect buildUp:147,drawDown:31

# %% [markdown]
# # plot flowing & shut-in periods

# %%
# points_type="allPoints"
points_type="majorTransients"
parameters={}
# parameters={"Order":polynomial_order,
#             "TanThre":deltaTangent_criterion,
#             "shutTr":minor_threshold_shutIn,
#            "flowTr":minor_threshold_Flowing}
detect_points_dict={"buildUp":transients.major_buildUp,
                   "drawDown":transients.major_drawDown}

buildup=detect_points_dict["buildUp"]
drawdown=detect_points_dict["drawDown"]
txt=f"buildup:{len(buildup)}, drawdown:{len(drawdown)}"
pprint(txt)
plot_whole=True
plot_details=True
plot_statistics=False
save=False
# folder_name=f"{method}/{points_type}/pointHalfWin_{point_halfWindow}_timeStep_{time_step}"
folder_name=""
# %run plot_N_save.ipynb
# Out:
# 'buildup:31, drawdown:31'
# ---initializing...
# ---plotting...
# findfont: Font family ['Arial Black'] not found. Falling back to DejaVu Sans.
# detected 62 points as breakpoints
# The plot is devided into 25 rows
# ------row 1-----detected points:[]
# ------row 2-----detected points:[2248]
# ------row 3-----detected points:[2477, 2804, 2891, 3095, 3594]
# ------row 4-----detected points:[4009, 4228, 4750]
# ------row 5-----detected points:[4899, 5304, 5445, 5985]
# ------row 6-----detected points:[6543]
# ------row 7-----detected points:[7284, 7551, 8003, 8368]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\OneDrive\Documents\cs\master_project\source_codes\venv\Scripts\transients_detection\source_code\plot_N_save.ipynb in <module>
#      14 plot_name=file_name
#      15
# ---> 16 PlotNSave(pressure_df,
#      17   rate_df,
#      18   detect_points_dict,
#
# ~\OneDrive\Documents\cs\master_project\source_codes\venv\Scripts\transients_detection\source_code\util\plot3.py in __init__(self, pressure_df, rate_df, points_detected_dict, ground_truth, data_inOneRow, plot_name, txt, filename_toSave_whole, filename_toSave_details, plot_statistics, plot_whole, plot_details, colum_names)
#      87                                 self.plot_whole,
#      88                                 filename_toSave_whole!="")
# ---> 89         self.plot_4_metrics_details(self.plot_details)
#      90
#      91     def produce_detectedPoints_lst(self):
#
# ~\OneDrive\Documents\cs\master_project\source_codes\venv\Scripts\transients_detection\source_code\util\plot3.py in plot_4_metrics_details(self, plot_show)
#     383             sub_rate_df=self.rate_df.loc[(rate_time >= start_time) & (rate_time <= end_time)]
#     384
# --> 385             self.plot_4_metrics(sub_pressure_df,
#     386                         sub_rate_df,
#     387                         sub_breakpoints,
#
# ~\OneDrive\Documents\cs\master_project\source_codes\venv\Scripts\transients_detection\source_code\util\plot3.py in plot_4_metrics(self, pressure_df, rate_df, points_detected, ground_truth, plot_show, plot_save)
#     316             **{'family': 'Arial Black', 'size': 22, 'weight': 'bold'},x=0.5, y=0.98)
#     317         if plot_show:
# --> 318             plt.show()
#     319         # print("plot_save",plot_save)
#     320         if plot_save:
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     334     """
#     335     _warn_if_gui_out_of_main_thread()
# --> 336     return _backend_mod.show(*args, **kwargs)
#     337
#     338
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib_inline\backend_inline.py in _fetch_figure_metadata(fig)
#     229     if _is_transparent(fig.get_facecolor()):
#     230         # the background is transparent
# --> 231         ticksLight = _is_light([label.get_color()
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib_inline\backend_inline.py in <listcomp>(.0)
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
# --> 234                                 for label in axis.get_ticklabels()])
#     235         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236             # there are one or more tick labels, all with the same lightness
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1383             self.majorTicks.append(tick)
#    1384             tick.gridline.set_visible(self._gridOnMajor)
# -> 1385             self._copy_tick_props(self.majorTicks[0], tick)
#    1386
#    1387         return self.majorTicks[:numticks]
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1350         dest.label2.update_from(src.label2)
#    1351         dest.tick1line.update_from(src.tick1line)
# -> 1352         dest.tick2line.update_from(src.tick2line)
#    1353         dest.gridline.update_from(src.gridline)
#    1354
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1296
#    1297         self._linestyle = other._linestyle
# -> 1298         self._marker = MarkerStyle(other._marker.get_marker(),
#    1299                                    other._marker.get_fillstyle())
#    1300         self._drawstyle = other._drawstyle
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     226         self._marker_function = None
#     227         self.set_fillstyle(fillstyle)
# --> 228         self.set_marker(marker)
#     229
#     230     def _recache(self):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     311         if not isinstance(marker, MarkerStyle):
#     312             self._marker = marker
# --> 313             self._recache()
#     314
#     315     def get_path(self):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\markers.py in _recache(self)
#     239         self._capstyle = 'butt'
#     240         self._filled = True
# --> 241         self._marker_function()
#     242
#     243     def __bool__(self):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\markers.py in _set_tickup(self)
#     746
#     747     def _set_tickup(self):
# --> 748         self._transform = Affine2D().scale(1.0, 1.0)
#     749         self._snap_threshold = 1.0
#     750         self._filled = False
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1843         if matrix is None:
#    1844             # A bit faster than np.identity(3).
# -> 1845             matrix = IdentityTransform._mtx.copy()
#    1846         self._mtx = matrix.copy()
#    1847         self._invalid = 0
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16600/3825507441.py in <module>
#      19 # folder_name=f"{method}/{points_type}/pointHalfWin_{point_halfWindow}_timeStep_{time_step}"
#      20 folder_name=""
# ---> 21 get_ipython().run_line_magic('run', 'plot_N_save.ipynb')
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# <decorator-gen-53> in run(self, parameter_s, runner, file_finder)
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2833                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2834                     if raise_exceptions:
# -> 2835                         result.raise_error()
#    2836                     elif not result.success:
#    2837                         break
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_16600/1413435424.py in <module>
#      14 plot_name=file_name
#      15
# ---> 16 PlotNSave(pressure_df,
#      17   rate_df,
#      18   detect_points_dict,
#
# ~\OneDrive\Documents\cs\master_project\source_codes\venv\Scripts\transients_detection\source_code\util\plot3.py in __init__(self, pressure_df, rate_df, points_detected_dict, ground_truth, data_inOneRow, plot_name, txt, filename_toSave_whole, filename_toSave_details, plot_statistics, plot_whole, plot_details, colum_names)
#      87                                 self.plot_whole,
#      88                                 filename_toSave_whole!="")
# ---> 89         self.plot_4_metrics_details(self.plot_details)
#      90
#      91     def produce_detectedPoints_lst(self):
#
# ~\OneDrive\Documents\cs\master_project\source_codes\venv\Scripts\transients_detection\source_code\util\plot3.py in plot_4_metrics_details(self, plot_show)
#     383             sub_rate_df=self.rate_df.loc[(rate_time >= start_time) & (rate_time <= end_time)]
#     384
# --> 385             self.plot_4_metrics(sub_pressure_df,
#     386                         sub_rate_df,
#     387                         sub_breakpoints,
#
# ~\OneDrive\Documents\cs\master_project\source_codes\venv\Scripts\transients_detection\source_code\util\plot3.py in plot_4_metrics(self, pressure_df, rate_df, points_detected, ground_truth, plot_show, plot_save)
#     316             **{'family': 'Arial Black', 'size': 22, 'weight': 'bold'},x=0.5, y=0.98)
#     317         if plot_show:
# --> 318             plt.show()
#     319         # print("plot_save",plot_save)
#     320         if plot_save:
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     334     """
#     335     _warn_if_gui_out_of_main_thread()
# --> 336     return _backend_mod.show(*args, **kwargs)
#     337
#     338
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib_inline\backend_inline.py in _fetch_figure_metadata(fig)
#     229     if _is_transparent(fig.get_facecolor()):
#     230         # the background is transparent
# --> 231         ticksLight = _is_light([label.get_color()
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib_inline\backend_inline.py in <listcomp>(.0)
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
# --> 234                                 for label in axis.get_ticklabels()])
#     235         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236             # there are one or more tick labels, all with the same lightness
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1383             self.majorTicks.append(tick)
#    1384             tick.gridline.set_visible(self._gridOnMajor)
# -> 1385             self._copy_tick_props(self.majorTicks[0], tick)
#    1386
#    1387         return self.majorTicks[:numticks]
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1350         dest.label2.update_from(src.label2)
#    1351         dest.tick1line.update_from(src.tick1line)
# -> 1352         dest.tick2line.update_from(src.tick2line)
#    1353         dest.gridline.update_from(src.gridline)
#    1354
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1296
#    1297         self._linestyle = other._linestyle
# -> 1298         self._marker = MarkerStyle(other._marker.get_marker(),
#    1299                                    other._marker.get_fillstyle())
#    1300         self._drawstyle = other._drawstyle
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     226         self._marker_function = None
#     227         self.set_fillstyle(fillstyle)
# --> 228         self.set_marker(marker)
#     229
#     230     def _recache(self):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     311         if not isinstance(marker, MarkerStyle):
#     312             self._marker = marker
# --> 313             self._recache()
#     314
#     315     def get_path(self):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\markers.py in _recache(self)
#     239         self._capstyle = 'butt'
#     240         self._filled = True
# --> 241         self._marker_function()
#     242
#     243     def __bool__(self):
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\markers.py in _set_tickup(self)
#     746
#     747     def _set_tickup(self):
# --> 748         self._transform = Affine2D().scale(1.0, 1.0)
#     749         self._snap_threshold = 1.0
#     750         self._filled = False
#
# c:\users\junec\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1843         if matrix is None:
#    1844             # A bit faster than np.identity(3).
# -> 1845             matrix = IdentityTransform._mtx.copy()
#    1846         self._mtx = matrix.copy()
#    1847         self._invalid = 0
#
# KeyboardInterrupt:

# %% [markdown]
# # plot periods & multi rate break points

# %%
points_type="allPoints"
# points_type="majorTransients"
parameters={}
# parameters={"Order":polynomial_order,
#             "TanThre":deltaTangent_criterion,
#             "shutTr":minor_threshold_shutIn,
#            "flowTr":minor_threshold_Flowing}
detect_points_dict=transients.allPointsStored

buildup=detect_points_dict["buildUp"]
drawdown=detect_points_dict["drawDown"]
txt=f"buildup:{len(buildup)}, drawdown:{len(drawdown)}"
pprint(txt)
plot_whole=True
plot_details=True
plot_statistics=False
save=False
# folder_name=f"{method}/{points_type}/pointHalfWin_{point_halfWindow}_timeStep_{time_step}"
folder_name=""
# %run plot_N_save.ipynb

# %%
points_type="allPoints"
# points_type="majorTransients"
parameters={}
# parameters={"Order":polynomial_order,
#             "TanThre":deltaTangent_criterion,
#             "shutTr":minor_threshold_shutIn,
#            "flowTr":minor_threshold_Flowing}
detect_points_dict=transients.allPointsStored

buildup=detect_points_dict["buildUp"]
drawdown=detect_points_dict["drawDown"]
txt=f"buildup:{len(buildup)}, drawdown:{len(drawdown)}"
pprint(txt)
plot_whole=True
plot_details=True
plot_statistics=False
save=False
# folder_name=f"{method}/{points_type}/pointHalfWin_{point_halfWindow}_timeStep_{time_step}"
folder_name=""
# %run plot_N_save.ipynb

# %%
points_type="allPoints"
# points_type="majorTransients"
parameters={}
# parameters={"Order":polynomial_order,
#             "TanThre":deltaTangent_criterion,
#             "shutTr":minor_threshold_shutIn,
#            "flowTr":minor_threshold_Flowing}
detect_points_dict=transients.allPointsStored

buildup=detect_points_dict["buildUp"]
drawdown=detect_points_dict["drawDown"]
txt=f"buildup:{len(buildup)}, drawdown:{len(drawdown)}"
pprint(txt)
plot_whole=True
plot_details=True
plot_statistics=False
save=False
# folder_name=f"{method}/{points_type}/pointHalfWin_{point_halfWindow}_timeStep_{time_step}"
folder_name=""
# %run plot_N_save.ipynb
